# %%
import os

# %%
pwd
# Out:
# 'C:\\Users\\SeshaSai Guna\\Python assignments\\Deep Learning cute\\Problem2'

# %%
os.chdir("F:\\assignment files\\Deep Learning Cute\\Problem2")

# %%
import pandas as pd
train=pd.read_csv("traindata-1548399384664.csv",encoding='latin-1')

# %%
test=pd.read_csv("testdata-1548399401363.csv",encoding='latin-1')
test
# Out:
#       Unnamed: 0            Name           effectiveness  \
# 0              0          biaxin  Considerably Effective
# 1              1        lamictal        Highly Effective
# 2              2        depakene    Moderately Effective
# 3              3         sarafem        Highly Effective
# 4              4        accutane        Highly Effective
# 5              5          biaxin    Marginally Effective
# 6              6   carbamazepine  Considerably Effective
# 7              7       ultram-er        Highly Effective
# 8              8        klonopin        Highly Effective
# 9              9         effexor    Marginally Effective
# 10            10          lyrica    Moderately Effective
# 11            11         valtrex        Highly Effective
# 12            12        provigil    Moderately Effective
# 13            13          maxalt        Highly Effective
# 14            14           xanax    Moderately Effective
# 15            15         chantix    Moderately Effective
# 16            16      ranitidine    Moderately Effective
# 17            17      prednisone  Considerably Effective
# 18            18       augmentin        Highly Effective
# 19            19          zyrtec        Highly Effective
# 20            20    methotrexate  Considerably Effective
# 21            21         fosamax  Considerably Effective
# 22            22           xanax  Considerably Effective
# 23            23     propranolol        Highly Effective
# 24            24        premarin    Moderately Effective
# 25            25         lovenox        Highly Effective
# 26            26      effexor-xr        Highly Effective
# 27            27        tirosint        Highly Effective
# 28            28         lexapro    Marginally Effective
# 29            29          renova    Moderately Effective
# ...          ...             ...                     ...
# 1006        1006       strattera    Marginally Effective
# 1007        1007           paxil    Moderately Effective
# 1008        1008        differin  Considerably Effective
# 1009        1009          ambien  Considerably Effective
# 1010        1010          biaxin        Highly Effective
# 1011        1011          nexium  Considerably Effective
# 1012        1012          nexium  Considerably Effective
# 1013        1013        provigil  Considerably Effective
# 1014        1014          requip        Highly Effective
# 1015        1015           paxil        Highly Effective
# 1016        1016         retin-a        Highly Effective
# 1017        1017          clomid  Considerably Effective
# 1018        1018        levaquin  Considerably Effective
# 1019        1019       neurontin        Highly Effective
# 1020        1020        prinivil    Marginally Effective
# 1021        1021   glucophage-xr    Moderately Effective
# 1022        1022        coumadin    Moderately Effective
# 1023        1023        differin    Moderately Effective
# 1024        1024          septra        Highly Effective
# 1025        1025        aygestin        Highly Effective
# 1026        1026       augmentin        Highly Effective
# 1027        1027         vyvanse        Highly Effective
# 1028        1028         chantix        Highly Effective
# 1029        1029        adipex-p    Marginally Effective
# 1030        1030         flonase        Highly Effective
# 1031        1031        accutane  Considerably Effective
# 1032        1032      proair-hfa        Highly Effective
# 1033        1033        accutane  Considerably Effective
# 1034        1034         divigel        Highly Effective
# 1035        1035  claripel-cream  Considerably Effective
#
#                         sideEffects  \
# 0                 Mild Side Effects
# 1                 Mild Side Effects
# 2               Severe Side Effects
# 3                   No Side Effects
# 4                 Mild Side Effects
# 5                   No Side Effects
# 6             Moderate Side Effects
# 7                 Mild Side Effects
# 8                   No Side Effects
# 9     Extremely Severe Side Effects
# 10            Moderate Side Effects
# 11                Mild Side Effects
# 12                  No Side Effects
# 13                Mild Side Effects
# 14                Mild Side Effects
# 15            Moderate Side Effects
# 16                  No Side Effects
# 17            Moderate Side Effects
# 18              Severe Side Effects
# 19                  No Side Effects
# 20              Severe Side Effects
# 21                  No Side Effects
# 22                Mild Side Effects
# 23                Mild Side Effects
# 24                Mild Side Effects
# 25                Mild Side Effects
# 26                Mild Side Effects
# 27                  No Side Effects
# 28              Severe Side Effects
# 29                Mild Side Effects
# ...                             ...
# 1006          Moderate Side Effects
# 1007          Moderate Side Effects
# 1008          Moderate Side Effects
# 1009              Mild Side Effects
# 1010  Extremely Severe Side Effects
# 1011                No Side Effects
# 1012                No Side Effects
# 1013              Mild Side Effects
# 1014                No Side Effects
# 1015              Mild Side Effects
# 1016              Mild Side Effects
# 1017          Moderate Side Effects
# 1018  Extremely Severe Side Effects
# 1019                No Side Effects
# 1020            Severe Side Effects
# 1021          Moderate Side Effects
# 1022            Severe Side Effects
# 1023                No Side Effects
# 1024                No Side Effects
# 1025                No Side Effects
# 1026              Mild Side Effects
# 1027                No Side Effects
# 1028              Mild Side Effects
# 1029              Mild Side Effects
# 1030                No Side Effects
# 1031            Severe Side Effects
# 1032                No Side Effects
# 1033          Moderate Side Effects
# 1034                No Side Effects
# 1035              Mild Side Effects
#
#                                               condition  \
# 0                                       sinus infection
# 1                                      bipolar disorder
# 2                                      bipolar disorder
# 3                                    bi-polar / anxiety
# 4                                          nodular acne
# 5                                       sinus infection
# 6                                               seizure
# 7        cervical disk degeneration and lower back pain
# 8                                        panic disorder
# 9                                            depression
# 10                                         fibromyalgia
# 11                                           cold sores
# 12                                      chronic fatigue
# 13                                             migraine
# 14                                              anxiety
# 15                                         stop smoking
# 16                                            heartburn
# 17                                 rheumatoid arthritis
# 18                                       diverticulitis
# 19                                   seasonal allergies
# 20                                  psoraitic arthritis
# 21                                            bone loss
# 22                                              anxiety
# 23                                     rapid heart rate
# 24                                   surgical memopause
# 25         blood thinning/ circulation during pregnancy
# 26                                    severe depression
# 27                     slow thyroid  & irregular period
# 28                                   depression/anxiety
# 29                                             wrinkles
# ...                                                 ...
# 1006                                                add
# 1007                                         depression
# 1008                                               acne
# 1009                                           insomnia
# 1010                                              ulcer
# 1011                  acid reflux / barrett's esophagus
# 1012                                        acid reflux
# 1013                                 multiple sclerosis
# 1014                             restless legs syndrome
# 1015                                    mild depression
# 1016                                               acne
# 1017                                        infertility
# 1018                                         bronchitis
# 1019                      epilepsy, depression and pain
# 1020  doctor said my blood pressure was somewhat hig...
# 1021                                   diabetes type ii
# 1022                                       heart murmer
# 1023                                         blackheads
# 1024                                  urinary infection
# 1025                                    hormone balance
# 1026                              severe abcessed tooth
# 1027                                               adhd
# 1028                                            smoking
# 1029                                        wieght loss
# 1030                                   sinus congestion
# 1031                                      acne vulgaris
# 1032                                             asthma
# 1033                                         serve acne
# 1034                                          menopause
# 1035                  acne scarring & hyperpigmentation
#
#                                          benefitsReview  \
# 0     The antibiotic may have destroyed bacteria cau...
# 1     Lamictal stabilized my serious mood swings. On...
# 2     Initial benefits were comparable to the brand ...
# 3     It controlls my mood swings. It helps me think...
# 4     Within one week of treatment superficial acne ...
# 5     By the end of the 10-day treatment I felt bett...
# 6     reduction in seizures reduction in seizures re...
# 7     Ive been taking Tramadol for 2 weeks now. Ive ...
# 8     I immediately stopped having panic attacks.  I...
# 9     the presumed benefits were to help with a seve...
# 10    some pain relief recieved minimized pain when ...
# 11    Significantly diminished the symptoms and size...
# 12    Treatment benefits were noticeable but not sub...
# 13    Very quick migraine relief with no nausea or d...
# 14    The xanax would act as a downer. It would calm...
# 15        The benefits were to eventually stop smoking.
# 16    to reduce acid production and stop acid reflux...
# 17    Stopped inflammation. Reduced need for pain ki...
# 18    Reduction of infection of acute uncomplicated ...
# 19    This medicine stopped post nasal drip, itching...
# 20    the treatment masked the psoriasis and what wa...
# 21    Helped build bone loss. Osteoporsis runs in my...
# 22    blood sugar controlled levels around 100-110, ...
# 23    I have suffered of rapid heart rate for someti...
# 24    The use of premarin reduced hot flashes and ke...
# 25    Lovenox is given in subsequent pregnancies to ...
# 26    i was severly depressed for weeks and would ju...
# 27    more energy and alertness, less fatigue & regu...
# 28                                    Increased libido.
# 29    The treatmeant benifits are that I showed a sl...
# ...                                                 ...
# 1006  Strattera seemed to give me some energy and fo...
# 1007  The treatment Benefits included feeling less a...
# 1008  reduced acne and refined skin texture. Helped ...
# 1009  For the treatment of insomnia, this drug induc...
# 1010  I had been having abdominal pain for quites so...
# 1011  Pain and heartburn from extreme acid reflux is...
# 1012  Reduced the acid reflux and heartburn that was...
# 1013  Provigil energizes me which improves my abilit...
# 1014  Requip has helped me sleep at night! no more h...
# 1015  I could see a dramatic difference in my mood w...
# 1016  Smoother skin with no pimples present. Lesseni...
# 1017  Increased my estrogen levels, started ovulatin...
# 1018                   I got much better in a few days.
# 1019  This medication was initially prescribed for p...
# 1020  Not very many at all. My Blood Pressure is sti...
# 1021  Regularly reduced fasting blood glucose by 20-...
# 1022                             reduced risk of stroke
# 1023  reduction in white heads however I think I sti...
# 1024  The urinary tract infection which causing freq...
# 1025  very beneficial. no issues or side effects and...
# 1026  infection, swelling and pain reduction with in...
# 1027  Helps me to concentrate and focus for a more p...
# 1028  When I took the medication as prescribed, If I...
# 1029  I'm just starting.I've been on it for a week n...
# 1030  I used it for six months and it worked like a ...
# 1031  Detoxing effect by pushing out the system thro...
# 1032  The albuterol relieved the constriction, irrit...
# 1033                    Serve Acne has turned to middle
# 1034  My overall mood, sense of well being, energy l...
# 1035  Up until 2 years ago, it worked really well on...
#
#                                       sideEffectsReview  \
# 0                         Some back pain, some nauseau.
# 1     Drowsiness, a bit of mental numbness. If you t...
# 2     Depakene has a very thin coating, which caused...
# 3               I didnt really notice any side effects.
# 4     Side effects included moderate to severe dry s...
# 5     I felt no significant side effects - perhaps s...
# 6     tired/sleepy very tired sleep and tired very t...
# 7     I have had no side effects so far. I hope it s...
# 8     I experienced no side effects.  I was not tire...
# 9     here we go.the initial effect would be dry mou...
# 10    signigicant swelling of hands and feet so sign...
# 11          Slight dizziness and tiredness, very minor.
# 12     nervousness, insomnia (if taken late in the day)
# 13                                    Very mild "buzz."
# 14    As I explained above. Addiction and drowsiness...
# 15    At first I experienced a slight headache and u...
# 16                            there are no side effects
# 17    Weight gain, osteoporosis, moon face; noticed ...
# 18    Disturbing and painful balanitis after 4 days,...
# 19          There were no treatment side effects noted.
# 20                        increasing all over body pain
# 21    I had no side effects. I always followed the d...
# 22    since i started taking metformin my weight los...
# 23    I started feeling dizzy whenever I get up from...
# 24    I experienced weight gain and sun sensitivity ...
# 25    There are no major side effects.  There is an ...
# 26    i very vivid dreams but i can live with this s...
# 27                         none, I felt not ill effects
# 28    Vivid dreams, nightmares, diarrhea, increased ...
# 29    The side effects are dry skin. I can't wax my ...
# ...                                                 ...
# 1006  See above.  Sleepiness and groggy-ness about 6...
# 1007  The Side effects I experienced from this drug ...
# 1008  Dry skin. After washing even with the mildest ...
# 1009  minimal side effects included mild grogginess ...
# 1010  After  taking the Biaxin for 9 days and feelin...
# 1011                           None that I am aware of.
# 1012  I did not experience side effects, although so...
# 1013  The only side effect is increased wakefulness ...
# 1014                                              None.
# 1015  The only side effects I had were temporary dec...
# 1016    Slight peeling and redness when treatment began
# 1017  Initially there were no problems, but after a ...
# 1018  Started having hallucinations. Began to see de...
# 1019  Sometimes I feel a bit nauseated if I take it ...
# 1020  Horrible headaches,sensation of fullness in my...
# 1021  Initial diarrhea. Must gradually titrate up to...
# 1022                                  excesive bleeding
# 1023  none. Although they do say it can cause dryene...
# 1024  I did not have any side effects that I am awar...
# 1025  I had no side effects wtih this drug. not sure...
# 1026                                   abdominal cramps
# 1027  The only negative side effect was the insomnia...
# 1028    Vivid dreams, and the loss of my intuitiveness.
# 1029     Jittery,increased heart rate.mild mood swings.
# 1030  There were no side effects short of a slight t...
# 1031  Hairloss, extreme dry skin, itchiness, raises ...
# 1032                I have experienced no side effects.
# 1033    Painfull muscles, problems with seeing at night
# 1034  No side effects of any kind were noted or appa...
# 1035  Have stopped using it and have also learned th...
#
#                                          commentsReview  Rating
# 0     Took the antibiotics for 14 days. Sinus infect...    high
# 1     Severe mood swings between hypomania and depre...    high
# 2     Depakote was prescribed to me by a Kaiser psyc...     low
# 3     This drug may not be for everyone but its wond...    high
# 4     Drug was taken in gelatin tablet at 0.5 mg per...    high
# 5     Basically the treatment did not seem to work. ...     low
# 6     took it for seizure took pills drank with wate...    high
# 7     Treating for neck, shoulder, arms, lower back,...    high
# 8     I started both klonopin and prozac together.  ...    high
# 9     family doctor initially prescribed wellbutin b...     low
# 10    I started on 50mg twice aday with out any pain...     low
# 11          2x 1000mg tablets every 12 hours for 1 day.    high
# 12    Took 100mg each day in the morning, sometimes ...  medium
# 13    This is the first migraine medicine I've found...    high
# 14    Once a day preferably at bedtime but if a situ...  medium
# 15    I was to take 1 small dosage pill twice a day ...  medium
# 16    take 2-3 times per day to aviod reflux acid. t...  medium
# 17    Taken daily orally once a day. Eventually tape...  medium
# 18        Augmentin 875 mg twice a day for three weeks.    high
# 19    I have taken this medicine once daily, in the ...    high
# 20    I started with 4 tabs and increased to 6 as th...     low
# 21    I took the drug weekly for about 8 years. Duri...    high
# 22    metformin 250 mg od, benicar 5 mg od , fosamax...    high
# 23                                    Details as above.  medium
# 24    I took premarin once daily for over twenty fiv...     low
# 25    I had to self administer the shots twice a day...    high
# 26    i found that the treatment plan has made life ...    high
# 27                       simply taking medication daily    high
# 28    Began at 5 mg, increased to 10mg after a few w...     low
# 29    I went to my doctor and asked for a wrinkle tr...  medium
# ...                                                 ...     ...
# 1006  I am nervous about taking a stimulant, but thi...     low
# 1007  I am unsure of what the treatment details mean...  medium
# 1008  Differin is a retinoid, supposedly the mildest...  medium
# 1009  Although this medication was immediately effec...    high
# 1010  To eliminate the side effects of hives, I had ...     low
# 1011  I take Nexium once a day in the morning. If I ...    high
# 1012  I took a pill everyday (with water) about a ho...    high
# 1013  The neurologist who first diagnosed the MS pre...    high
# 1014                Take 1 pill 2 hours before bedtime.    high
# 1015  I take one 20 mg. pill once a day at the same ...    high
# 1016  I began taking Retin-A because my skin was hav...    high
# 1017  After a first successful pregnancy, my attempt...    high
# 1018  By day 3 on the pills I was losing touch with ...     low
# 1019  As I stated, increasing the dosage of this med...    high
# 1020  I want to clarify that except for the HBP I ha...     low
# 1021  I would take one 500 mg pill every time I ate,...  medium
# 1022                                      14.5 mg daily     low
# 1023  used 3-5 times a week depnding on occurance of...  medium
# 1024  I took two tablets of bactrim 2x per day with ...    high
# 1025  took prescrition daily and that was it. pretty...    high
# 1026     pills 2 xs daily with food and plenty of water    high
# 1027      Vyvanse 50mg taken once daily in the morning.    high
# 1028           One pill twice daily with alot of water.    high
# 1029  i only have 46 pounds left to get to my goal w...  medium
# 1030  I had one spray per nostril bedore bed.  It ke...    high
# 1031  Treatment period is 3 months/12 weeks. Dosage ...  medium
# 1032  I use the albuterol as needed because of aller...    high
# 1033  This drug is highly teratogenic ,females must ...    high
# 1034  Divigel is a topically applied Bio-Identical H...    high
# 1035               Stopped using it for the time being.    high
#
# [1036 rows x 9 columns]

# %%
train=train.drop('Unnamed: 0',axis=1)
test=test.drop('Unnamed: 0',axis=1)
test.shape
train.shape
# Out:
# (3107, 8)

# %%
train["var1"] = train["effectiveness"]+"."+train["sideEffects"]+"."+train["condition"]+"."+ train["benefitsReview"]+"."+train["sideEffectsReview"]+"."+train["commentsReview"]

# %%
test["var2"] = test["effectiveness"]+"."+test["sideEffects"]+"."+test["condition"]+"."+ test["benefitsReview"]+"."+test["sideEffectsReview"]+"."+test["commentsReview"]

# %%
## Define the sequence lengths, max number of words and embedding dimensions
MAX_SEQUENCE_LENGTH = 1000   # Sequence length of each sentence. If more, crop. If less, pad with zeros
MAX_NB_WORDS = 25000        # Top 20000 frequently occuring words

# %%
## Import Libraries 
import numpy as np      # for array operations
import pandas as pd     # for reading data operations

from keras.preprocessing.text import Tokenizer          # for tokenizing text
from keras.preprocessing.sequence import pad_sequences  # for padding sentences with zeros. To make the sentence length same
from keras.utils import to_categorical                  # for one-hot encoding of the labels
from keras.layers import Dense, Input, Flatten, Dropout, BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, GlobalMaxPool1D, Embedding
from keras.models import Sequential
# Out:
# D:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train["var1"] = train["var1"].astype("str")
test["var2"] = test["var2"].astype("str")

# %%
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)   # get the frequently occuring words
tokenizer.fit_on_texts(train.var1)           
train_sequences = tokenizer.texts_to_sequences(train.var1)
test_sequences = tokenizer.texts_to_sequences(test.var2)

word_index = tokenizer.word_index               # dictionary containing words and their index
print(tokenizer.word_index)                   # print to check
print('Found %s unique tokens.' % len(word_index)) # total words in the corpus
train_data = pad_sequences(train_sequences, maxlen=MAX_SEQUENCE_LENGTH) # get only the top frequent words on train
test_data = pad_sequences(test_sequences, maxlen=MAX_SEQUENCE_LENGTH)   # get only the top frequent words on test

print(train_data.shape)
print(test_data.shape)
# Out:
# {'i': 1, 'the': 2, 'to': 3, 'and': 4, 'a': 5, 'of': 6, 'my': 7, 'it': 8, 'was': 9, 'side': 10, 'effects': 11, 'in': 12, 'for': 13, 'effective': 14, 'that': 15, 'have': 16, 'with': 17, 'not': 18, 'this': 19, 'on': 20, 'no': 21, 'had': 22, 'but': 23, 'is': 24, 'as': 25, 'me': 26, 'after': 27, 'at': 28, 'day': 29, 'take': 30, 'taking': 31, 'pain': 32, 'mild': 33, 'highly': 34, 'or': 35, 'drug': 36, 'so': 37, 'very': 38, 'be': 39, 'when': 40, 'more': 41, 'severe': 42, 'medication': 43, 'did': 44, 'were': 45, 'from': 46, 'would': 47, '\r\r': 48, 'time': 49, 'also': 50, 'one': 51, 'if': 52, 'about': 53, 'up': 54, 'am': 55, 'treatment': 56, 'which': 57, 'depression': 58, 'considerably': 59, 'all': 60, 'skin': 61, 'days': 62, 'took': 63, '2': 64, 'an': 65, 'first': 66, 'been': 67, 'only': 68, 'any': 69, 'has': 70, 'years': 71, 'sleep': 72, 'before': 73, 'then': 74, 'mg': 75, 'get': 76, 'you': 77, 'by': 78, 'started': 79, 'some': 80, 'feel': 81, 'like': 82, 'night': 83, 'months': 84, 'moderate': 85, '3': 86, 'are': 87, 'acne': 88, 'anxiety': 89, 'weeks': 90, 'there': 91, 'felt': 92, 'back': 93, 'dose': 94, 'because': 95, 'other': 96, 'once': 97, 'out': 98, 'now': 99, 'symptoms': 100, 'doctor': 101, 'much': 102, 'over': 103, 'daily': 104, 'taken': 105, 'pill': 106, 'week': 107, 'do': 108, 'every': 109, 'still': 110, 'better': 111, '1': 112, 'prescribed': 113, 'off': 114, 'just': 115, 'two': 116, 'could': 117, 'than': 118, 'none': 119, 'use': 120, 'blood': 121, 'can': 122, 'effect': 123, 'morning': 124, 'able': 125, 'weight': 126, 'hours': 127, 'work': 128, 'even': 129, 'well': 130, 'times': 131, 'they': 132, 'went': 133, 'during': 134, 'will': 135, 'less': 136, 'feeling': 137, 'stopped': 138, 'life': 139, 'dry': 140, 'increased': 141, 'used': 142, 'loss': 143, 'helped': 144, 'without': 145, 'moderately': 146, 'few': 147, '4': 148, 'within': 149, '5': 150, 'really': 151, 'dosage': 152, 'stomach': 153, 'again': 154, 'while': 155, 'made': 156, 'since': 157, 'help': 158, "didn't": 159, 'go': 160, 'control': 161, 'down': 162, 'experienced': 163, 'never': 164, 'due': 165, 'reduced': 166, 'high': 167, 'however': 168, 'good': 169, 'long': 170, 'per': 171, 'month': 172, 'face': 173, 'infection': 174, 'benefits': 175, 'pressure': 176, 'year': 177, "don't": 178, '6': 179, 'being': 180, 'too': 181, 'having': 182, 'normal': 183, 'he': 184, 'little': 185, 'what': 186, 'extremely': 187, 'nausea': 188, 'hair': 189, 'tried': 190, 'away': 191, 'patient': 192, 'got': 193, 'bad': 194, 'noticed': 195, 'using': 196, '10': 197, "i'm": 198, 'three': 199, 'mood': 200, 'stop': 201, 'most': 202, 'began': 203, 'problems': 204, 'became': 205, 'needed': 206, 'medicine': 207, 'mouth': 208, 'body': 209, 'these': 210, 'ineffective': 211, 'experience': 212, 'headaches': 213, 'found': 214, 'think': 215, 'need': 216, 'your': 217, 'almost': 218, 'worked': 219, 'period': 220, 'tablet': 221, 'twice': 222, 'them': 223, 'see': 224, 'same': 225, 'know': 226, 'several': 227, 'she': 228, 'caused': 229, 'completely': 230, 'longer': 231, "it's": 232, '20': 233, 'headache': 234, 'sometimes': 235, "i've": 236, 'insomnia': 237, 'going': 238, 'problem': 239, 'bed': 240, 'though': 241, 'around': 242, 'pills': 243, 'until': 244, 'into': 245, 'another': 246, 'each': 247, 'many': 248, 'may': 249, 'heart': 250, 'through': 251, 'seemed': 252, 'gain': 253, 'told': 254, 'getting': 255, 'next': 256, '30': 257, 'results': 258, 'increase': 259, 'tired': 260, 'energy': 261, 'migraine': 262, 'put': 263, 'relief': 264, 'cream': 265, 'improved': 266, 'lower': 267, 'hour': 268, 'low': 269, 'later': 270, 'make': 271, 'last': 272, 'decreased': 273, 'great': 274, 'acid': 275, 'such': 276, 'minutes': 277, 'slight': 278, 'does': 279, 'where': 280, 'worse': 281, 'sure': 282, 'eat': 283, 'marginally': 284, 'try': 285, 'people': 286, 'food': 287, 'levels': 288, 'water': 289, 'nothing': 290, 'eyes': 291, 'myself': 292, 'usually': 293, 'although': 294, 'cleared': 295, 'who': 296, 'given': 297, 'drugs': 298, 'fa ...
# Found 14365 unique tokens.
# (3107, 1000)
# (1036, 1000)

# %%
train_labels = train["rating"]
test_labels = test["Rating"]

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()                  # converts the character array to numeric array. Assigns levels to unique labels.
le.fit(train_labels)
train_labels = le.transform(train_labels)
test_labels = le.transform(test_labels)

#print(le.classes_)
print(np.unique(train_labels, return_counts=True))
print(np.unique(test_labels, return_counts=True))
# Out:
# (array([0, 1, 2], dtype=int64), array([1780,  661,  666], dtype=int64))
# (array([0, 1, 2], dtype=int64), array([549, 241, 246], dtype=int64))

# %%
labels_train = to_categorical(np.asarray(train_labels))
labels_test = to_categorical(np.asarray(test_labels))
print('Shape of data tensor:', train_data.shape)
print('Shape of label tensor:', labels_train.shape)
print('Shape of label tensor:', labels_test.shape)
# Out:
# Shape of data tensor: (3107, 1000)
# Shape of label tensor: (3107, 3)
# Shape of label tensor: (1036, 3)

# %%
from keras.regularizers import l2
from keras.layers import Dense, Input, LSTM, ActivityRegularization


print('Training model.')
EMBEDDING_DIM = 100

model = Sequential()
model.add(Embedding(MAX_NB_WORDS,
                    EMBEDDING_DIM,
                    input_length=MAX_SEQUENCE_LENGTH
                    ))
model.add(Conv1D(32, 3, activation='relu'))
model.add(Conv1D(64, 3, activation='relu'))
model.add(GlobalMaxPool1D())
model.add(Dropout(0.25))

model.add(Dense(256, activation='relu'))
model.add(Dense(3, activation='softmax'))
# Out:
# Training model.

# %%
EMBEDDING_DIM = 100

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 1000, 100)         2500000
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 998, 32)           9632
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 996, 64)           6208
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               16640
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 2,533,251
# Trainable params: 2,533,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_data, labels_train,
          batch_size=32,
          epochs=3,
          validation_split=0.3)
# Out:
# Train on 2174 samples, validate on 933 samples
# Epoch 1/3
# 2174/2174 [==============================] - 12s 5ms/step - loss: 0.0627 - acc: 0.9802 - val_loss: 0.6704 - val_acc: 0.7706
# Epoch 2/3
# 2174/2174 [==============================] - 12s 6ms/step - loss: 0.0394 - acc: 0.9880 - val_loss: 0.7227 - val_acc: 0.7771
# Epoch 3/3
# 2174/2174 [==============================] - 12s 6ms/step - loss: 0.0301 - acc: 0.9899 - val_loss: 0.7774 - val_acc: 0.7588

# %%
model.evaluate(test_data, labels_test)
# Out:
# 1036/1036 [==============================] - 1s 1ms/step
# [0.7494571937902553, 0.7596525098826434]

# %%
model.save_weights("model_cnn.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
#with dropout
from keras.regularizers import l2
from keras.layers import Dense, Input, LSTM, ActivityRegularization


print('Training model.')
EMBEDDING_DIM = 64

model = Sequential()
model.add(Embedding(MAX_NB_WORDS,
                    EMBEDDING_DIM,
                    input_length=MAX_SEQUENCE_LENGTH
                    ))
model.add(Conv1D(32, 3, activation='relu'))
model.add(Conv1D(32, 3, activation='relu'))
model.add(GlobalMaxPool1D())
#model.add(Dropout(0.25))

ActivityRegularization(l1=0.01, l2=0.001)

model.add(Dense(512, activation='relu'))
model.add(Dense(3, activation='softmax'))
# Out:
# Training model.

# %%
from keras.optimizers import Adam
adam = Adam(lr=0.001)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, 1000, 64)          1600000
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 998, 32)           6176
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 996, 32)           3104
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 32)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               16896
# _________________________________________________________________
# dense_10 (Dense)             (None, 3)                 1539
# =================================================================
# Total params: 1,627,715
# Trainable params: 1,627,715
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_data, labels_train,
          batch_size=32,
          epochs=3,
          validation_split=0.3)
# Out:
# Train on 2174 samples, validate on 933 samples
# Epoch 1/3
# 2174/2174 [==============================] - 8s 4ms/step - loss: 0.0845 - acc: 0.9798 - val_loss: 0.6518 - val_acc: 0.7706
# Epoch 2/3
# 2174/2174 [==============================] - 8s 4ms/step - loss: 0.0336 - acc: 0.9931 - val_loss: 0.6995 - val_acc: 0.7878
# Epoch 3/3
# 2174/2174 [==============================] - 8s 4ms/step - loss: 0.0119 - acc: 0.9968 - val_loss: 0.7609 - val_acc: 0.7760

# %%
model.evaluate(test_data, labels_test)
# Out:
# 1036/1036 [==============================] - 1s 743us/step
# [0.7577437812527175, 0.7741312743614079]

# %%
model.save_weights("model_cnn1.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
#building lstm model
model = Sequential() # Call Sequential to initialize a network
model.add(Embedding(input_dim = MAX_NB_WORDS,
                    input_length=MAX_SEQUENCE_LENGTH,
                    output_dim =128)) # Add an embedding layer which represents each unique token as a vector
model.add(LSTM(50, return_sequences=True)) # Add an LSTM layer
model.add(LSTM(50, return_sequences=False))
model.add(Dense(3, activation='softmax'))

# %%
model.compile(optimizer=adam,                  # 'Adam' is a variant of gradient descent technique
              loss='categorical_crossentropy', # categorical_crossentropy for multi-class classification
              metrics=['accuracy'])            # These metrics are computed for evaluating and stored in history

# %%
model.evaluate(test_data, labels_test)
# Out:
# 1036/1036 [==============================] - 4s 4ms/step
# [2.6995592862942965, 0.5366795365644698]

# %%
model.fit(train_data, labels_train, epochs=10, validation_split=0.25)
# Out:
# Train on 2330 samples, validate on 777 samples
# Epoch 1/10
# 2330/2330 [==============================] - 60s 26ms/step - loss: 0.9644 - acc: 0.5755 - val_loss: 0.9510 - val_acc: 0.5701
# Epoch 2/10
# 2330/2330 [==============================] - 66s 28ms/step - loss: 0.6798 - acc: 0.7150 - val_loss: 1.1106 - val_acc: 0.5650
# Epoch 3/10
# 2330/2330 [==============================] - 65s 28ms/step - loss: 0.3292 - acc: 0.8807 - val_loss: 1.1999 - val_acc: 0.5766
# Epoch 4/10
# 2330/2330 [==============================] - 69s 29ms/step - loss: 0.1237 - acc: 0.9609 - val_loss: 1.5833 - val_acc: 0.5418
# Epoch 5/10
# 2330/2330 [==============================] - 89s 38ms/step - loss: 0.0469 - acc: 0.9876 - val_loss: 1.8578 - val_acc: 0.5637
# Epoch 6/10
# 2330/2330 [==============================] - 84s 36ms/step - loss: 0.0284 - acc: 0.9914 - val_loss: 2.2902 - val_acc: 0.5740
# Epoch 7/10
# 2330/2330 [==============================] - 67s 29ms/step - loss: 0.0111 - acc: 0.9948 - val_loss: 2.1550 - val_acc: 0.5470
# Epoch 8/10
# 2330/2330 [==============================] - 78s 33ms/step - loss: 0.0073 - acc: 0.9970 - val_loss: 2.3956 - val_acc: 0.5547
# Epoch 9/10
# 2330/2330 [==============================] - 82s 35ms/step - loss: 0.0047 - acc: 0.9974 - val_loss: 2.4872 - val_acc: 0.5856
# Epoch 10/10
# 2330/2330 [==============================] - 72s 31ms/step - loss: 0.0038 - acc: 0.9983 - val_loss: 2.5279 - val_acc: 0.5894

# %%
def create_conv_model():
    model_conv = Sequential()
    model_conv.add(Embedding(input_dim = MAX_NB_WORDS, input_length=MAX_SEQUENCE_LENGTH,output_dim =128))
    model_conv.add(Dropout(0.2))
    model_conv.add(Conv1D(64, 5, activation='relu'))
    model_conv.add(MaxPooling1D(pool_size=4))
    model_conv.add(LSTM(10,return_sequences=True))
    model_conv.add(LSTM(10,return_sequences=False))
    model_conv.add(Dense(3, activation='sigmoid'))
    model_conv.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model_conv

# %%
model_conv = create_conv_model()
history = model.fit(train_data, labels_train, epochs=5, validation_split=0.30)
# Out:
# Train on 2174 samples, validate on 933 samples
# Epoch 1/5
# 2174/2174 [==============================] - 8s 4ms/step - loss: 0.0033 - acc: 0.9977 - val_loss: 0.8790 - val_acc: 0.7738
# Epoch 2/5
# 2174/2174 [==============================] - 8s 3ms/step - loss: 0.0027 - acc: 0.9977 - val_loss: 0.8945 - val_acc: 0.7717
# Epoch 3/5
# 2174/2174 [==============================] - 8s 4ms/step - loss: 0.0027 - acc: 0.9982 - val_loss: 0.9101 - val_acc: 0.7696
# Epoch 4/5
# 2174/2174 [==============================] - 8s 4ms/step - loss: 0.0026 - acc: 0.9982 - val_loss: 0.9199 - val_acc: 0.7738
# Epoch 5/5
# 2174/2174 [==============================] - 9s 4ms/step - loss: 0.0026 - acc: 0.9986 - val_loss: 0.9452 - val_acc: 0.7749

# %%
model.evaluate(test_data, labels_test)
# Out:
# 1036/1036 [==============================] - 1s 729us/step
# [0.9116453239586363, 0.7876447878749214]

# %%
model.save_weights("model_lstm.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
train_acc = history.history['acc']
train_loss = history.history['loss']

val_acc = history.history['val_acc']
val_loss = history.history['val_loss']

# %%
from matplotlib import pyplot as plt #plt is a visualization module in matplotlib.  
# %matplotlib inline 
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(train_loss)
plt.plot(val_loss)

plt.subplot(1,2,2)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(train_acc)
plt.plot(val_acc)
